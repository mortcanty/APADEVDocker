# %% [markdown]
# ## Testbed

# %%
import networkx as nx
import matplotlib.pylab as pylab
from apa import APA
pylab.rcParams['figure.figsize'] = 16, 12

# %%
G = nx.DiGraph()

# %%
G.clear()

# %%
G.add_nodes_from(['Origin','Source Material','Enrichment Feed','DU Enrichment Product'])

# %%
G.add_edges_from([('Origin','Source Material')])

# %%
# %matplotlib inline

# %%
nx.draw_networkx(G,{'Origin':(1,10),'Source Material':(2,9),'Enrichment Feed':(5,9),'DU Enrichment Product':(7,8)},True)
